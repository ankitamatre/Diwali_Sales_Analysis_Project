# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
s = r"C:\Users\Ankita\OneDrive\Desktop\Diwali Sales Project\Diwali Sales Data.csv"
print(s)
# Out:
# C:\Users\Ankita\OneDrive\Desktop\Diwali Sales Project\Diwali Sales Data.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(s, na_values = ["", "NA"], keep_default_na = False)
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# 2  23924.0     NaN       NaN
# 3  23912.0     NaN       NaN
# 4  23877.0     NaN       NaN

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(["Status", "unnamed1"], axis = 1, inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(8)

# %%
df = df.drop_duplicates(keep = "first").reset_index(drop = True)
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11238  1000695      Manning  P00296942      M     18-25   19               1
# 11239  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11240  1001209        Oshin  P00201342      F     36-45   40               0
# 11241  1004023       Noonan  P00059442      M     36-45   37               0
# 11242  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11238     Maharashtra   Western         Chemical           Office       4
# 11239         Haryana  Northern       Healthcare       Veterinary       3
# 11240  Madhya Pradesh   Central          Textile           Office       4
# 11241       Karnataka  Southern      Agriculture           Office       3
# 11242     Maharashtra   Western       Healthcare           Office       3
#
#         Amount
# 0      23952.0
# 1      23934.0
# 2      23924.0
# 3      23912.0
# 4      23877.0
# ...        ...
# 11238    370.0
# 11239    367.0
# 11240    213.0
# 11241    206.0
# 11242    188.0
#
# [11243 rows x 13 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11243 entries, 0 to 11242
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age Group         11243 non-null  object
#  5   Age               11243 non-null  int64
#  6   Marital_Status    11243 non-null  int64
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11231 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.isna().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
def sonu(df):
    cat = list(df.columns[df.dtypes == "object"])

    for i in df.columns:
        if i in cat:
            mode = df[i].mode()[0]
            df[i] = df[i].fillna(mode)
        else:
            mean = df[i].mean()
            df[i] = df[i].fillna(mean)

# %%
sonu(df)

# %%
df.isna().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.dtypes
# Out:
# User_ID               int64
# Cust_name            object
# Product_ID           object
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status        int64
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# dtype: object

# %%
cat = []
con = []

for k in df.columns:
    if df[k].dtypes == "object":
        cat.append(k)
    else:
        con.append(k)

# %%
cat
# Out:
# ['Cust_name',
#  'Product_ID',
#  'Gender',
#  'Age Group',
#  'State',
#  'Zone',
#  'Occupation',
#  'Product_Category']

# %%
con
# Out:
# ['User_ID', 'Age', 'Marital_Status', 'Orders', 'Amount']

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.124300e+04  11243.000000    11243.000000  11243.000000  11243.000000
# mean   1.003005e+06     35.422841        0.420261      2.488749   9454.084982
# std    1.716141e+03     12.756369        0.493623      1.114960   5218.941128
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001494e+06     27.000000        0.000000      1.000000   5444.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8111.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12672.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df.groupby(by = ["Gender"]).count()
# Out:
#         User_ID  Cust_name  Product_ID  Age Group   Age  Marital_Status  \
# Gender
# F          7838       7838        7838       7838  7838            7838
# M          3405       3405        3405       3405  3405            3405
#
#         State  Zone  Occupation  Product_Category  Orders  Amount
# Gender
# F        7838  7838        7838              7838    7838    7838
# M        3405  3405        3405              3405    3405    3405

# %%
df.sort_values(by = ["State"])
# Out:
#       User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 2284  1005100    Spruell  P00196542      F     51-55   55               0
# 9504  1005127    Drucker  P00105142      F     46-50   49               0
# 7808  1005397   Kargatis  P00121642      F     18-25   23               0
# 7806  1003850      Smith  P00223542      F     18-25   23               0
# 6671  1002420      Franz  P00113142      F     51-55   52               0
# ...       ...        ...        ...    ...       ...  ...             ...
# 8541  1000957   Goldenen  P00240842      F     36-45   40               1
# 9965  1000316   Zrebassa  P00206742      F       55+   77               1
# 6800  1003807      Suman  P00359642      M     36-45   36               0
# 9508  1004819     Swetha  P00184342      F     36-45   37               0
# 9793  1002164  McCrossin  P00222042      F     36-45   44               0
#
#                State      Zone  Occupation       Product_Category  Orders  \
# 2284  Andhra Pradesh  Southern  Healthcare                   Food       4
# 9504  Andhra Pradesh  Southern    Aviation  Electronics & Gadgets       2
# 7808  Andhra Pradesh  Southern  Healthcare                 Beauty       3
# 7806  Andhra Pradesh  Southern        Govt  Electronics & Gadgets       3
# 6671  Andhra Pradesh  Southern  Automobile                 Beauty       1
# ...              ...       ...         ...                    ...     ...
# 8541     Uttarakhand   Central  Automobile     Clothing & Apparel       3
# 9965     Uttarakhand   Central       Media     Clothing & Apparel       4
# 6800     Uttarakhand   Central    Aviation     Clothing & Apparel       2
# 9508     Uttarakhand   Central    Aviation  Electronics & Gadgets       4
# 9793     Uttarakhand   Central    Chemical     Clothing & Apparel       3
#
#        Amount
# 2284  15295.0
# 9504   4003.0
# 7808   6142.0
# 7806   6143.0
# 6671   7610.0
# ...       ...
# 8541   5397.0
# 9965   3565.0
# 6800   7168.0
# 9508   3996.0
# 9793   3726.0
#
# [11243 rows x 13 columns]

# %%
top_states = df["State"].value_counts().nlargest(5).index
filtered_df = df[df["State"].isin(top_states)]

plt.figure(figsize = (10, 4))
sns.countplot(data = filtered_df, x = "State", order = top_states, edgecolor = "black")
plt.title("Countplot for Top 5 States")
plt.show()

# %%
top_zone = df["Zone"].value_counts().nlargest(5).index
filtered_df = df[df["Zone"].isin(top_zone)]

plt.figure(figsize = (10, 4))
sns.countplot(data = filtered_df, x = "Zone", order = top_zone, edgecolor = "black")
plt.title("Countplot for Zone")
plt.show()

# %%
top_occupation = df["Occupation"].value_counts().nlargest(5).index
filtered_df = df[df["Occupation"].isin(top_occupation)]

plt.figure(figsize = (10, 4))
sns.countplot(data = filtered_df, x = "Occupation", order = top_occupation, edgecolor = "black")
plt.title("countplot for Occupation")
plt.show()

# %%
top_product_category = df["Product_Category"].value_counts().nlargest(5).index
filtered_df = df[df["Product_Category"].isin(top_product_category)]

plt.figure(figsize = (10, 4))
sns.countplot(data = filtered_df, x = "Product_Category", order = top_product_category, edgecolor = "black")
plt.title("Countplot for Product Category")
plt.show()

# %%
tab = pd.crosstab(df["State"], df["Cust_name"])
print(tab)
# Out:
# Cust_name         Aaron  Aarushi  Aastha  Aayush  Aayushi  Abelman  Abhijeet  \
# State
# Andhra Pradesh        0        0       3       1        1        1         0
# Bihar                 0        1       1       1        0        0         0
# Delhi                 1        0       5       3        1        1         0
# Gujarat               0        1       0       0        0        2         1
# Haryana               0        0       0       0        1        0         0
# Himachal Pradesh      0        0       1       1        0        0         0
# Jharkhand             0        0       0       2        0        0         0
# Karnataka             1        2       5       1        1        0         1
# Kerala                0        0       4       0        0        1         1
# Madhya Pradesh        0        3       1       2        1        1         0
# Maharashtra           1        0       1       1        1        2         2
# Punjab                0        1       0       0        0        0         0
# Rajasthan             0        1       2       1        0        0         0
# Telangana             0        1       0       0        0        0         0
# Uttar Pradesh         1        4       2       1        2        1         2
# Uttarakhand           1        0       2       0        0        1         0
#
# Cust_name         Abhijit  Abhimanyu  Abhishek  ...  Zeldin  Zettner  Zewe  \
# State                                           ...
# Andhra Pradesh          2          0         0  ...       0        2     0
# Bihar                   1          0         0  ...       1        0     0
# Delhi                   2          2         0  ...       0        1     1
# Gujarat                 0          0         1  ...       0        0     0
# Haryana                 0          0         0  ...       0        0     0
# Himachal Pradesh        4          1         0  ...       0        1     0
# Jharkhand               0          0         0  ...       0        0     0
# Karnataka               1          1         2  ...       4        2     2
# Kerala                  0          0         0  ...       0        0     1
# Madhya Pradesh          0          0         1  ...       0        1     0
# Maharashtra             1          2         1  ...       0        0     0
# Punjab                  0          0         1  ...       1        0     1
# Rajasthan               0          0         0  ...       0        0     0
# Telangana               0          0         0  ...       0        0     0
# Uttar Pradesh           2          1         2  ...       1        1     1
# Uttarakhand             0          0         0  ...       1        1     1
#
# Cust_name         Zic  Zrebassa  Zuschuss  Zydlo  Zypern  liebe  percer
# State
# Andhra Pradesh      0         0         0      0       1      0       0
# Bihar               0         0         0      0       1      1       0
# Delhi               0         0         1      1       1      1       0
# Gujarat             0         0         0      0       1      0       0
# Haryana             0         0         1      1       0      2       2
# Himachal Pradesh    0         0         0      0       0      0       1
# Jharkhand           0         1         0      0       0      0       1
# Karnataka           1         1         1      1       1      0       1
# Kerala              0         0         0      1       2      0       0
# Madhya Pradesh      0         0         0      0       0      0       0
# Maharashtra         1         1         1      0       0      3       0
# Punjab              0         0         0      1       0      0       0
# Rajasthan           0         0         0      0       0      0       1
# Telangana           0         0         0      0       1      0       0
# Uttar Pradesh       1         1         1      1       1      1       1
# Uttarakhand         1         1         1      1       1      0       0
#
# [16 rows x 1250 columns]

# %%
top_state = df["State"].value_counts().nlargest(10).index
top_customers = df["Cust_name"].value_counts().nlargest(10).index
filtered_df = df[df["State"].isin(top_state) & df["Cust_name"].isin(top_customers)]

tab = pd.crosstab(filtered_df["State"], filtered_df["Cust_name"])
tab = tab.reindex(index = top_state, columns = top_customers, fill_value = 0)

plt.figure(figsize = (12, 7))
sns.heatmap(data = tab, annot = True, fmt = "d", cmap = "coolwarm")
plt.title("Heatmap Customer Name Wise For Top 10 States")
plt.show()

# %%
plt.figure(figsize = (10, 4))
sns.histplot(data = df, x = "Orders", kde = True, edgecolor = "black")
plt.title("Histplot for Orders")
plt.show()

# %%
top_user_id = df["User_ID"].value_counts().nlargest(5).index
filtered_df = df[df["User_ID"].isin(top_user_id)]

plt.figure(figsize = (10, 4))
sns.histplot(data = filtered_df, x = "User_ID", kde = True, edgecolor = "black")
plt.title("Histplot for User_ID")
plt.show()

# %%
top_marital_status = df["Marital_Status"].value_counts().nlargest(5).index
filtered_df = df[df["Marital_Status"].isin(top_marital_status)]

plt.figure(figsize = (10, 4))
sns.histplot(data = filtered_df, x = "Marital_Status", kde = True, edgecolor = "black")
plt.title("Histplot for Material Status")
plt.show()

# %%
top_amount = df["Amount"].value_counts().nlargest(5).index
filtered_df = df[df["Amount"].isin(top_amount)]

plt.figure(figsize = (10, 4))
sns.histplot(data = filtered_df, x = "Amount", kde = True, edgecolor = "black")
plt.title("Histplot for Amount")
plt.show()

# %%
plt.figure(figsize = (10, 4))
sns.scatterplot(data = df, x = "Orders", y = "Amount", hue = "Gender")
plt.title("Scatterplot for Orders & Amount")
plt.show()

# %%
plt.figure(figsize = (10, 4))
sns.boxplot(data = df, x = "Gender", y = "Orders")
plt.title("Boxplot for Gender & Orders")
plt.show()

# %%
sns.pairplot(data = df, hue = "Gender")

# %%
plt.figure(figsize = (10, 4))
sns.regplot(data = df, x = "Orders", y = "Amount", line_kws = {"color":"red"})
plt.title("Regplot For Order wise Amount")
plt.show()

# %%
import os
sonu = r"C:\Users\Ankita\OneDrive\Desktop\Diwali Sales Project"
os.chdir(sonu)

# %%
df.to_csv("Diwali Sales Dataset Clean.csv", index = False)

# %%
# %pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in c:\users\ankita\anaconda3\lib\site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (2.10.3)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\ankita\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (2.1.3)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\ankita\anaconda3\lib\site-packages (from ydata-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in c:\users\ankita\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in c:\users\ankita\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ankita\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ankita\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ankita\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ankita\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ankita\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ankita\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ankita\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ankita\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\ankita\anaconda3\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ankita\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ankita\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\ankita\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ankita\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\ankita\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\ankita\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ankita\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ankita\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ankita\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ankita\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.4.26)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\ankita\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\ankita\anaconda3\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\ankita\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (24.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\ankita\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Requirement already satisfied: puremagic in c:\users\ankita\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\ankita\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df, title = "Diwali Sales Report")

# %%
import os
s = r"C:\Users\Ankita\OneDrive\Desktop\Diwali Sales Project"
os.chdir(s)

# %%
profile.to_file("Diwali Sales Report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 13/13 [00:00<00:00, 165.53it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
